# %%
#!pip install requests

# %%
import requests
url = 'https://www.cbr-xml-daily.ru/daily_json.js'
response = requests.get(url)

# %%
print(response)
print(response.status_code)
# Out:
# <Response [200]>
# 200

# %%
#Task 3.1
response = requests.get('https://www.cbr-xml-daily.ru/daily.xml')

# %%
url = 'https://www.cbr-xml-daily.ru/daily_json.js'
response = requests.get(url)
print(response)
print(response.text)
# Out:
# <Response [200]>
# {
#     "Date": "2023-01-21T11:30:00+03:00",
#     "PreviousDate": "2023-01-20T11:30:00+03:00",
#     "PreviousURL": "\/\/www.cbr-xml-daily.ru\/archive\/2023\/01\/20\/daily_json.js",
#     "Timestamp": "2023-01-22T13:00:00+03:00",
#     "Valute": {
#         "AUD": {
#             "ID": "R01010",
#             "NumCode": "036",
#             "CharCode": "AUD",
#             "Nominal": 1,
#             "Name": "Австралийский доллар",
#             "Value": 47.5029,
#             "Previous": 47.5318
#         },
#         "AZN": {
#             "ID": "R01020A",
#             "NumCode": "944",
#             "CharCode": "AZN",
#             "Nominal": 1,
#             "Name": "Азербайджанский манат",
#             "Value": 40.3915,
#             "Previous": 40.4981
#         },
#         "GBP": {
#             "ID": "R01035",
#             "NumCode": "826",
#             "CharCode": "GBP",
#             "Nominal": 1,
#             "Name": "Фунт стерлингов Соединенного королевства",
#             "Value": 84.8638,
#             "Previous": 85.3286
#         },
#         "AMD": {
#             "ID": "R01060",
#             "NumCode": "051",
#             "CharCode": "AMD",
#             "Nominal": 100,
#             "Name": "Армянских драмов",
#             "Value": 17.3289,
#             "Previous": 17.3693
#         },
#         "BYN": {
#             "ID": "R01090B",
#             "NumCode": "933",
#             "CharCode": "BYN",
#             "Nominal": 1,
#             "Name": "Белорусский рубль",
#             "Value": 26.1007,
#             "Previous": 26.0773
#         },
#         "BGN": {
#             "ID": "R01100",
#             "NumCode": "975",
#             "CharCode": "BGN",
#             "Nominal": 1,
#             "Name": "Болгарский лев",
#             "Value": 37.9704,
#             "Previous": 38.1549
#         },
#         "BRL": {
#             "ID": "R01115",
#             "NumCode": "986",
#             "CharCode": "BRL",
#             "Nominal": 1,
#             "Name": "Бразильский реал",
#             "Value": 13.1692,
#             "Previous": 13.5243
#         },
#         "HUF": {
#             "ID": "R01135",
#             "NumCode": "348",
#             "CharCode": "HUF",
#             "Nominal": 100,
#             "Name": "Венгерских форинтов",
#             "Value": 18.7862,
#             "Previous": 18.8487
#         },
#         "VND": {
#             "ID": "R01150",
#             "NumCode": "704",
#             "CharCode": "VND",
#             "Nominal": 10000,
#             "Name": "Вьетнамских донгов",
#             "Value": 29.0894,
#             "Previous": 29.1662
#         },
#         "HKD": {
#             "ID": "R01200",
#             "NumCode": "344",
#             "CharCode": "HKD",
#             "Nominal": 10,
#             "Name": "Гонконгских долларов",
#             "Value": 87.8189,
#             "Previous": 88.073
#         },
#         "GEL": {
#             "ID": "R01210",
#             "NumCode": "981",
#             "CharCode": "GEL",
#             "Nominal": 1,
#             "Name": "Грузинский лари",
#             "Value": 25.7223,
#             "Previous": 25.7901
#         },
#         "DKK": {
#             "ID": "R01215",
#             "NumCode": "208",
#             "CharCode": "DKK",
#             "Nominal": 10,
#             "Name": "Датских крон",
#             "Value": 99.8177,
#             "Previous": 10.0301
#         },
#         "AED": {
#             "ID": "R01230",
#             "NumCode": "784",
#             "CharCode": "AED",
#             "Nominal": 1,
#             "Name": "Дирхам ОАЭ",
#             "Value": 18.6952,
#             "Previous": 18.744
#         },
#         "USD": {
#             "ID": "R01235",
#             "NumCode": "840",
#             "CharCode": "USD",
#             "Nominal": 1,
#             "Name": "Доллар США",
#             "Value": 68.6656,
#             "Previous": 68.8467
#         },
#         "EUR": {
#             "ID": "R01239",
#             "NumCode": "978",
#             "CharCode": "EUR",
#             "Nominal": 1,
#             "Name": "Евро",
#             "Value": 74.3434,
#             "Previous": 74.4058
#         },
#         "EGP": {
#             "ID": "R01240",
#             "NumCode": "818",
#             "CharCode": "EGP",
#             "Nominal": 10,
#             "Name": "Египетских фунтов",
#             "Value": 23.0253,
#             "Previous": 23.2361
#         },
#         "INR": {
#             "ID": "R01270",
#             "NumCode": "356",
#             "CharCode": "INR",
#             "Nominal": 100,
#             "Name": "Индийских рупий",
#             "Value": 84.3218,
#             "Previous": 84.2484
#         },
#         "IDR": {
#             "ID": "R01280",
#             "NumCode": "360",
#             "CharCode": "IDR",
#             "Nominal": 10000,
#             "Name": "Индонезийских рупий",
#             "Value": 45.4348,
#             "Previous": 45.4824
#         },
#         "KZT": {
#             "ID": "R01335",
#             "NumCode": "398",
#             "CharCode": "KZT",
#             "Nominal": 100,
#             "Name": "Казахстанских тенге",
#             "Value": 14.838,
#             "Previous": 14.8268
#         },
#         "CAD": {
#             "ID": "R01350",
#             "NumCode": "124",
#             "CharCode": "CAD",
#             "Nominal": 1,
#             "Name": "Канадский доллар",
#             "Value": 50.9691,
#             "Previous": 51.229
#         },
#         "QAR": {
#             "ID": "R01355",
#             "NumCode": "634",
#             "CharCode": "QAR",
#             "Nominal": 1,
#             "Name": "Катарский риал",
#             "Value": 18.8642,
#             "Previous": 18.9139
#         },
#         "KGS": {
#             "ID": "R01370",
#             "NumCode": "417",
#             "CharCode": "KGS",
#             "Nominal": 100,
#             "Name": "Киргизских сомов",
#             "Value": 79.7696,
#             "Previous": 80.1579
#         },
#         "CNY": {
#             "ID": "R01375",
#             "NumCode": "156",
#             "CharCode": "CNY",
#             "Nominal": 1,
#             "Name": "Китайский юань",
#             "Value": 10.1227,
#             "Previous": 10.132
#         },
#         "MDL": {
#             "ID": "R01500",
#             "NumCode": "498",
#             "CharCode": "MDL",
#             "Nominal": 10,
#             "Name": "Молдавских леев",
#             "Value": 36.1885,
#             "Previous": 36.2586
#         },
#         "NZD": {
#             "ID": "R01530",
#             "NumCode": "554",
#             "CharCode": "NZD",
#             "Nominal": 1,
#             "Name": "Новозеландский доллар",
#             "Value": 43.9529,
#             "Previous": 44.234
#         },
#         "NOK": {
#             "ID": "R01535",
#             "NumCode": "578",
#             "CharCode": "NOK",
#             "Nominal": 10,
#             "Name": "Норвежских крон",
#             "Value": 69.3676,
#             "Previous": 69.2483
#         },
#         "PLN": {
#             "ID": "R01565",
#             "NumCode": "985",
#             "CharCode": "PLN",
#             "Nominal": 1,
#             "Name": "Польский злотый",
#             "Value": 15.7885,
#             "Previous": 15.8319
#         },
#         "RON": {
#             "ID": "R01585F",
#             "NumCode": "946",
#             "CharCode": "RON",
#             "Nominal": 1,
#             "Name": "Румынский лей",
#             "Value": 15.1076,
#             "Previous": 15.1142
#         },
#         "XDR": {
#             "ID": "R01589",
#             "NumCode": "960",
#             "CharCode": "XDR",
#             "Nominal": 1,
#             "Name": "СДР (специальные права заимствования)",
#             "Value": 92.6409,
#             "Previous": 92.9286
#         },
#         "SGD": {
#             "ID": "R01625",
#             "NumCode": "702",
#             "CharCode": "SGD",
#             "Nominal": 1,
#             "Name": "Сингапурский доллар",
#             "Value": 51.9093,
#             "Previous": 52.0737
#         },
#         "TJS": {
#             "ID": "R01670",
#             "NumCode": "972",
#             "CharCode": "TJS",
#             "Nominal": 10,
#             "Name": "Таджикских сомони",
#             "Value": 66.9021,
#             "Previous": 67.0942
#         },
#         "THB": {
#             "ID": "R01675",
#             "NumCode": "764",
#             "CharCode": "THB",
#             "Nominal": 10,
#             "Name": "Таиландских батов",
#             "Value": 20.9159,
#             "Previous": 20.8275
#         },
#         "TRY": {
#             "ID": "R01700J",
#             "NumCode": "949",
#             "CharCode": "TRY",
#             "Nominal": 10,
#             "Name": "Турецких лир",
#             "Value": 36.5416,
#             "Previous": 36.6459
#         },
#         "TMT": {
#             "ID": "R01710A",
#             "NumCode": "934",
#             "CharCode": "TMT",
#             "Nominal": 1,
#             "Name": "Новый туркменский манат",
#             "Value": 19.6187,
#             "Previous": 19.6705
#         },
#         "UZS": {
#             "ID": "R01717",
#             "NumCode": "860",
#             "CharCode": "UZS",
#             "Nominal": 10000,
#             "Name": "Узбекских сумов",
#             "Value": 60.8468,
#             "Previous": 60.9747
#         },
#         "UAH": {
#             "ID": "R01720",
#             "NumCode": "980",
#             "CharCode": "UAH",
#             "Nominal": 10,
#             "Name": "Украинских гривен",
#             "Value": 18.5926,
#             "Previous": 18.7072
#         },
#         "CZK": {
#             "ID": "R01760",
#             "NumCode": "203",
#             "CharCode": "CZK",
#             "Nominal": 10,
#             "Name": "Чешских крон",
#             "Value": 31.0423,
#             "Previous": 31.1481
#         },
#         "SEK": {
#             "ID": "R01770",
#             "NumCode": "752",
#             "CharCode": "SEK",
#             "Nominal": 10,
#             "Name": "Шведских крон",
#             "Value": 66.6546,
#             "Previous": 66.7896
#         },
#         "CHF": {
#             "ID": "R01775",
#             "NumCode": "756",
#             "CharCode": "CHF",
#             "Nominal": 1,
#             "Name": "Швейцарский франк",
#             "Value": 74.6122,
#             "Previous": 75.1355
#         },
#         "RSD": {
#             "ID": "R01805F",
#             "NumCode": "941",
#             "CharCode": "RSD",
#             "Nominal": 100,
#             "Name": "Сербских динаров",
#             "Value": 63.4047,
#             "Previous": 63.3453
#         },
#         "ZAR": {
#             "ID": "R01810",
#             "NumCode": "710",
#             "CharCode": "ZAR",
#             "Nominal": 10,
#             "Name": "Южноафриканских рэндов",
#             "Value": 39.8135,
#             "Previous": 40.1492
#         },
#         "KRW": {
#             "ID": "R01815",
#             "NumCode": "410",
#             "CharCode": "KRW",
#             "Nominal": 1000,
#             "Name": "Вон Республики Корея",
#             "Value": 55.5772,
#             "Previous": 55.8775
#         },
#         "JPY": {
#             "ID": "R01820",
#             "NumCode": "392",
#             "CharCode": "JPY",
#             "Nominal": 100,
#             "Name": "Японских иен",
#             "Value": 53.374,
#             "Previous": 53.6189
#         }
#     }
# }

# %%
from pprint import pprint
currencies = response.json()
pprint(currencies)
# Out:
# {'Date': '2023-01-21T11:30:00+03:00',
#  'PreviousDate': '2023-01-20T11:30:00+03:00',
#  'PreviousURL': '//www.cbr-xml-daily.ru/archive/2023/01/20/daily_json.js',
#  'Timestamp': '2023-01-22T13:00:00+03:00',
#  'Valute': {'AED': {'CharCode': 'AED',
#                     'ID': 'R01230',
#                     'Name': 'Дирхам ОАЭ',
#                     'Nominal': 1,
#                     'NumCode': '784',
#                     'Previous': 18.744,
#                     'Value': 18.6952},
#             'AMD': {'CharCode': 'AMD',
#                     'ID': 'R01060',
#                     'Name': 'Армянских драмов',
#                     'Nominal': 100,
#                     'NumCode': '051',
#                     'Previous': 17.3693,
#                     'Value': 17.3289},
#             'AUD': {'CharCode': 'AUD',
#                     'ID': 'R01010',
#                     'Name': 'Австралийский доллар',
#                     'Nominal': 1,
#                     'NumCode': '036',
#                     'Previous': 47.5318,
#                     'Value': 47.5029},
#             'AZN': {'CharCode': 'AZN',
#                     'ID': 'R01020A',
#                     'Name': 'Азербайджанский манат',
#                     'Nominal': 1,
#                     'NumCode': '944',
#                     'Previous': 40.4981,
#                     'Value': 40.3915},
#             'BGN': {'CharCode': 'BGN',
#                     'ID': 'R01100',
#                     'Name': 'Болгарский лев',
#                     'Nominal': 1,
#                     'NumCode': '975',
#                     'Previous': 38.1549,
#                     'Value': 37.9704},
#             'BRL': {'CharCode': 'BRL',
#                     'ID': 'R01115',
#                     'Name': 'Бразильский реал',
#                     'Nominal': 1,
#                     'NumCode': '986',
#                     'Previous': 13.5243,
#                     'Value': 13.1692},
#             'BYN': {'CharCode': 'BYN',
#                     'ID': 'R01090B',
#                     'Name': 'Белорусский рубль',
#                     'Nominal': 1,
#                     'NumCode': '933',
#                     'Previous': 26.0773,
#                     'Value': 26.1007},
#             'CAD': {'CharCode': 'CAD',
#                     'ID': 'R01350',
#                     'Name': 'Канадский доллар',
#                     'Nominal': 1,
#                     'NumCode': '124',
#                     'Previous': 51.229,
#                     'Value': 50.9691},
#             'CHF': {'CharCode': 'CHF',
#                     'ID': 'R01775',
#                     'Name': 'Швейцарский франк',
#                     'Nominal': 1,
#                     'NumCode': '756',
#                     'Previous': 75.1355,
#                     'Value': 74.6122},
#             'CNY': {'CharCode': 'CNY',
#                     'ID': 'R01375',
#                     'Name': 'Китайский юань',
#                     'Nominal': 1,
#                     'NumCode': '156',
#                     'Previous': 10.132,
#                     'Value': 10.1227},
#             'CZK': {'CharCode': 'CZK',
#                     'ID': 'R01760',
#                     'Name': 'Чешских крон',
#                     'Nominal': 10,
#                     'NumCode': '203',
#                     'Previous': 31.1481,
#                     'Value': 31.0423},
#             'DKK': {'CharCode': 'DKK',
#                     'ID': 'R01215',
#                     'Name': 'Датских крон',
#                     'Nominal': 10,
#                     'NumCode': '208',
#                     'Previous': 10.0301,
#                     'Value': 99.8177},
#             'EGP': {'CharCode': 'EGP',
#                     'ID': 'R01240',
#                     'Name': 'Египетских фунтов',
#                     'Nominal': 10,
#                     'NumCode': '818',
#                     'Previous': 23.2361,
#                     'Value': 23.0253},
#             'EUR': {'CharCode': 'EUR',
#                     'ID': 'R01239',
#                     'Name': 'Евро',
#                     'Nominal': 1,
#                     'NumCode': '978',
#                     'Previous': 74.4058,
#                     'Value': 74.3434},
#             'GBP': {'CharCode': 'GBP',
#                     'ID': 'R01035',
#                     'Name': 'Фунт стерлингов Соединенного королевства',
#                     'Nominal': 1,
#                     'NumCode': '826',
#                     'Previous': 85.3286,
#                     'Value': 84.8638},
#             'GEL': {'CharCode': 'GEL',
#                     'ID': 'R01210',
#                     'Name': 'Грузинский лари',
#                     'Nominal': 1,
#                     'NumCode': '981',
#                     'Previous': 25.7901,
#                     'Value': 25.7223},
#             'HKD': {'CharCode': 'HKD',
#                     'ID': 'R01200',
#                     'Name': 'Гонконгских долларов',
#                     'Nominal': 10,
#                     'NumCode': '344',
#                     'Previous': 88.073,
#                     'Value': 87.8189},
#             'HUF': {'CharCode': 'HUF',
#                     'ID': 'R01135',
#                     'Name': 'Венгерских форинтов',
#                     'Nominal': 100,
#                     'NumCode': '348',
#                     'Previous': 18.8487,
#                     'Value': 18.7862},
#             'IDR': {'CharCode': 'IDR',
#                     'ID': 'R01280',
#                     'Name': 'Индонезийских рупий',
#                     'Nominal': 10000,
#                     'NumCode': '360',
#                     'Previous': 45.4824,
#                     'Value': 45.4348},
#             'INR': {'CharCode': 'INR',
#                     'ID': 'R01270',
#                     'Name': 'Индийских рупий',
#                     'Nominal': 100,
#                     'NumCode': '356',
#                     'Previous': 84.2484,
#                     'Value': 84.3218},
#             'JPY': {'CharCode': 'JPY',
#                     'ID': 'R01820',
#                     'Name': 'Японских иен',
#                     'Nominal': 100,
#                     'NumCode': '392',
#                     'Previous': 53.6189,
#                     'Value': 53.374},
#             'KGS': {'CharCode': 'KGS',
#                     'ID': 'R01370',
#                     'Name': 'Киргизских сомов',
#                     'Nominal': 100,
#                     'NumCode': '417',
#                     'Previous': 80.1579,
#                     'Value': 79.7696},
#             'KRW': {'CharCode': 'KRW',
#                     'ID': 'R01815',
#                     'Name': 'Вон Республики Корея',
#                     'Nominal': 1000,
#                     'NumCode': '410',
#                     'Previous': 55.8775,
#                     'Value': 55.5772},
#             'KZT': {'CharCode': 'KZT',
#                     'ID': 'R01335',
#                     'Name': 'Казахстанских тенге',
#                     'Nominal': 100,
#                     'NumCode': '398',
#                     'Previous': 14.8268,
#                     'Value': 14.838},
#             'MDL': {'CharCode': 'MDL',
#                     'ID': 'R01500',
#                     'Name': 'Молдавских леев',
#                     'Nominal': 10,
#                     'NumCode': '498',
#                     'Previous': 36.2586,
#                     'Value': 36.1885},
#             'NOK': {'CharCode': 'NOK',
#                     'ID': 'R01535',
#                     'Name': 'Норвежских крон',
#                     'Nominal': 10,
#                     'NumCode': '578',
#                     'Previous': 69.2483,
#                     'Value': 69.3676},
#             'NZD': {'CharCode': 'NZD',
#                     'ID': 'R01530',
#                     'Name': 'Новозеландский доллар',
#                     'Nominal': 1,
#                     'NumCode': '554',
#                     'Previous': 44.234,
#                     'Value': 43.9529},
#             'PLN': {'CharCode': 'PLN',
#                     'ID': 'R01565',
#                     'Name': 'Польский злотый',
#                     'Nominal': 1,
#                     'NumCode': '985',
#                     'Previous': 15.8319,
#                     'Value': 15.7885},
#             'QAR': {'CharCode': 'QAR',
#                     'ID': 'R01355',
#                     'Name': 'Катарский риал',
#                     'Nominal': 1,
#                     'NumCode': '634',
#                     'Previous': 18.9139,
#                     'Value': 18.8642},
#             'RON': {'CharCode': 'RON',
#                     'ID': 'R01585F',
#                     'Name': 'Румынский лей',
#                     'Nominal': 1,
#                     'NumCode': '946',
#                     'Previous': 15.1142,
#                     'Value': 15.1076},
#             'RSD': {'CharCode': 'RSD',
#                     'ID': 'R01805F',
#                     'Name': 'Сербских динаров',
#                     'Nominal': 100,
#                     'NumCode': '941',
#                     'Previous': 63.3453,
#                     'Value': 63.4047},
#             'SEK': {'CharCode': 'SEK',
#                     'ID': 'R01770',
#                     'Name': 'Шведских крон',
#                     'Nominal': 10,
#                     'NumCode': '752',
#                     'Previous': 66.7896,
#                     'Value': 66.6546},
#             'SGD': {'CharCode': 'SGD',
#                     'ID': 'R01625',
#                     'Name': 'Сингапурский доллар',
#                     'Nominal': 1,
#                     'NumCode': '702',
#                     'Previous': 52.0737,
#                     'Value': 51.9093},
#             'THB': {'CharCode': 'THB',
#                     'ID': 'R01675',
#                     'Name': 'Таиландских батов',
#                     'Nominal': 10,
#                     'NumCode': '764',
#                     'Previous': 20.8275,
#                     'Value': 20.9159},
#             'TJS': {'CharCode': 'TJS',
#                     'ID': 'R01670',
#                     'Name': 'Таджикских сомони',
#                     'Nominal': 10,
#                     'NumCode': '972',
#                     'Previous': 67.0942,
#                     'Value': 66.9021},
#             'TMT': {'CharCode': 'TMT',
#                     'ID': 'R01710A',
#                     'Name': 'Новый туркменский манат',
#                     'Nominal': 1,
#                     'NumCode': '934',
#                     'Previous': 19.6705,
#                     'Value': 19.6187},
#             'TRY': {'CharCode': 'TRY',
#                     'ID': 'R01700J',
#                     'Name': 'Турецких лир',
#                     'Nominal': 10,
#                     'NumCode': '949',
#                     'Previous': 36.6459,
#                     'Value': 36.5416},
#             'UAH': {'CharCode': 'UAH',
#                     'ID': 'R01720',
#                     'Name': 'Украинских гривен',
#                     'Nominal': 10,
#                     'NumCode': '980',
#                     'Previous': 18.7072,
#                     'Value': 18.5926},
#             'USD': {'CharCode': 'USD',
#                     'ID': 'R01235',
#                     'Name': 'Доллар США',
#                     'Nominal': 1,
#                     'NumCode': '840',
#                     'Previous': 68.8467,
#                     'Value': 68.6656},
#             'UZS': {'CharCode': 'UZS',
#                     'ID': 'R01717',
#                     'Name': 'Узбекских сумов',
#                     'Nominal': 10000,
#                     'NumCode': '860',
#                     'Previous': 60.9747,
#                     'Value': 60.8468},
#             'VND': {'CharCode': 'VND',
#                     'ID': 'R01150',
#                     'Name': 'Вьетнамских донгов',
#                     'Nominal': 10000,
#                     'NumCode': '704',
#                     'Previous': 29.1662,
#                     'Value': 29.0894},
#             'XDR': {'CharCode': 'XDR',
#                     'ID': 'R01589',
#                     'Name': 'СДР (специальные права заимствования)',
#                     'Nominal': 1,
#                     'NumCode': '960',
#                     'Previous': 92.9286,
#                     'Value': 92.6409},
#             'ZAR': {'CharCode': 'ZAR',
#                     'ID': 'R01810',
#                     'Name': 'Южноафриканских рэндов',
#                     'Nominal': 10,
#                     'NumCode': '710',
#                     'Previous': 40.1492,
#                     'Value': 39.8135}}}

# %%
pprint(currencies['Valute']['EUR'])
# Out:
# {'CharCode': 'EUR',
#  'ID': 'R01239',
#  'Name': 'Евро',
#  'Nominal': 1,
#  'NumCode': '978',
#  'Previous': 74.4058,
#  'Value': 74.3434}

# %%
# Task 3.2
print(currencies['Valute']['CZK']['Name'])
# Out:
# Чешских крон
