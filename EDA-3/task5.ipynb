# %%
# !pip install category_encoders

# %%
import category_encoders as ce

# %%
import pandas as pd
# инициализируем информацию об одежде
clothing_list = [
    ['xxs', 'dress'],
    ['xxs', 'skirt'],
    ['xs', 'dress'],
    ['s', 'skirt'],
    ['m', 'dress'],
    ['l', 'shirt'],
    ['s', 'coat'],
    ['m', 'coat'],
    ['xxl', 'shirt'],
    ['l', 'dress']
]

clothing = pd.DataFrame(clothing_list, columns = ['size',  'type'])
clothing
# Out:
#   size   type
# 0  xxs  dress
# 1  xxs  skirt
# 2   xs  dress
# 3    s  skirt
# 4    m  dress
# 5    l  shirt
# 6    s   coat
# 7    m   coat
# 8  xxl  shirt
# 9    l  dress

# %%
of = ce.OrdinalEncoder()
data_bin = of.fit_transform(clothing['size'])
clothing1 = pd.concat([clothing, data_bin], axis=1)
clothing1
# Out:
#    size   type  size
# 0   xxs  dress     1
# 1   xxs  skirt     1
# 2    xs  dress     2
# 3     s  skirt     3
# 4     m  dress     4
# 5     l  shirt     5
# 6     s   coat     3
# 7     m   coat     4
# 8   xxl  shirt     6
# 9     l  dress     5

# %%
ohe = ce.OneHotEncoder(cols=['type'], use_cat_names=True)
type_bin = ohe.fit_transform(clothing['type'])
clothing2 = pd.concat([clothing1, type_bin], axis=1)

clothing2
# Out:
#    size   type  size  type_dress  type_skirt  type_shirt  type_coat
# 0   xxs  dress     1           1           0           0          0
# 1   xxs  skirt     1           0           1           0          0
# 2    xs  dress     2           1           0           0          0
# 3     s  skirt     3           0           1           0          0
# 4     m  dress     4           1           0           0          0
# 5     l  shirt     5           0           0           1          0
# 6     s   coat     3           0           0           0          1
# 7     m   coat     4           0           0           0          1
# 8   xxl  shirt     6           0           0           1          0
# 9     l  dress     5           1           0           0          0

# %%
clothing3 = pd.get_dummies(clothing, columns=['type'] )
clothing3
# Out:
#   size  type_coat  type_dress  type_shirt  type_skirt
# 0  xxs          0           1           0           0
# 1  xxs          0           0           0           1
# 2   xs          0           1           0           0
# 3    s          0           0           0           1
# 4    m          0           1           0           0
# 5    l          0           0           1           0
# 6    s          1           0           0           0
# 7    m          1           0           0           0
# 8  xxl          0           0           1           0
# 9    l          0           1           0           0

# %%
df_wine = pd.read_csv('data/wine_cleared.zip')
print(df_wine.shape[1])
df_wine2 = pd.get_dummies(df_wine, columns=['taster_name'])
print(df_wine2.shape[1])
print(df_wine2.shape[1] - df_wine.shape[1])
df_wine.groupby(by='taster_name').count()

ose = ce.OneHotEncoder(cols=['taster_name'])
type_taser = ose.fit_transform(df_wine['taster_name'])
type_taser.shape[1]
df_wine3 = pd.concat([df_wine, type_taser], axis=1)
df_wine3.shape[1]
df_wine3.shape[1] - df_wine.shape[1]
# df_wine3.info()
df_wine2.info()
# Out:
# 13
# 32
# 19
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unnamed: 0                      129971 non-null  int64
#  1   country                         129908 non-null  object
#  2   description                     129971 non-null  object
#  3   designation                     129971 non-null  object
#  4   points                          129971 non-null  int64
#  5   price                           129971 non-null  float64
#  6   province                        129908 non-null  object
#  7   region_1                        129971 non-null  object
#  8   taster_twitter_handle           129971 non-null  object
#  9   title                           129971 non-null  object
#  10  variety                         129970 non-null  object
# ...

# %%
data = pd.read_csv('data/wine_cleared.zip')
w1 = data.shape[1]
encoder = ce.OneHotEncoder(cols=['taster_name'])
type_bin = encoder.fit_transform(data['taster_name'])
data = pd.concat([data, type_bin], axis=1)

w2 = data.shape[1]
print(w2 - w1)
# data.info()
# Out:
# 20

# %%
bin_encdoder = ce.BinaryEncoder(cols=['type'])
type_bin = bin_encdoder.fit_transform(clothing['type'])
clothing4 = pd.concat([clothing, type_bin], axis=1)
clothing4
# Out:
#   size   type  type_0  type_1  type_2
# 0  xxs  dress       0       0       1
# 1  xxs  skirt       0       1       0
# 2   xs  dress       0       0       1
# 3    s  skirt       0       1       0
# 4    m  dress       0       0       1
# 5    l  shirt       0       1       1
# 6    s   coat       1       0       0
# 7    m   coat       1       0       0
# 8  xxl  shirt       0       1       1
# 9    l  dress       0       0       1

# %%
bin_encdoder_country = ce.BinaryEncoder(cols=['country'])
type_bin_country = bin_encdoder_country.fit_transform(df_wine['country'])
df_wine4 = pd.concat([df_wine, type_bin_country], axis=1)
df_wine4.shape[1] - df_wine.shape[1]
# Out:
# 6

# %%
df_wine.groupby(by='taster_twitter_handle').count()
# Out:
#                        Unnamed: 0  country  description  designation  points  \
# taster_twitter_handle
# @AnneInVino                  3685     3676         3685         3685    3685
# @JoeCz                       5147     5145         5147         5147    5147
# @bkfiona                       27       27           27           27      27
# @gordone_cellars             4177     4177         4177         4177    4177
# @kerinokeefe                10776    10776        10776        10776   10776
# @laurbuzz                    1835     1832         1835         1835    1835
# @mattkettmann                6332     6332         6332         6332    6332
# @paulgwine                   9532     9531         9532         9532    9532
# @suskostrzewa                1085     1080         1085         1085    1085
# @vboone                      9537     9537         9537         9537    9537
# @vossroger                  25514    25512        25514        25514   25514
# ...

# %%
be = ce.BinaryEncoder(cols=['taster_twitter_handle'])
type_bin = be.fit_transform(df_wine['taster_twitter_handle'])
type_bin.shape[1]
# Out:
# 5

# %%
list_of_dicts = [
 {'product': 'Product1', 'price': 1200, 'payment_type': 'Mastercard'},
 {'product': 'Product2', 'price': 3600, 'payment_type': 'Visa'},
 {'product': 'Product3', 'price': 7500, 'payment_type': 'Amex'}
]
df = pd.DataFrame(list_of_dicts)
df
# Out:
#     product  price payment_type
# 0  Product1   1200   Mastercard
# 1  Product2   3600         Visa
# 2  Product3   7500         Amex

# %%
df1 = ce.BinaryEncoder(cols=['product']).fit_transform(df['product'])
df2 = ce.BinaryEncoder(cols=['payment_type']).fit_transform(df['payment_type'])
result = pd.concat([df, df1, df2], axis=1)
result
# Out:
#     product  price payment_type  product_0  product_1  payment_type_0  \
# 0  Product1   1200   Mastercard          0          1               0
# 1  Product2   3600         Visa          1          0               1
# 2  Product3   7500         Amex          1          1               1
#
#    payment_type_1
# 0               1
# 1               0
# 2               1
